# %%
import pygame
import math

pygame.init()
#Font
Font = pygame.font.SysFont('Arial',35)

# I have pygame here so it doesn't have to initialize every time we repeat the game.
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.6.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#Colors
black = (0, 0, 0)
white = (255, 255, 255)
red = (255, 0, 0)
blue = (0,0,255)
grey = (169, 169, 169)

window_size = (700,700)

position = []
blue_possible = [] #Auxilary list to represent player 2 move on the small board
red_possible = [] #Auxilary list to represent player 1 move on the small board
Win_con_op = [] #Auxilary list for the big board
Big_board_position = [] #Position on the big board. 
Big_board_possible_red = []
Big_board_possible_blue = []
ref_N = []

board_size = 2
n = board_size**2
next_game = (n + 1,n + 1)

for a in range(board_size):
    position.append([])
    blue_possible.append([])
    red_possible.append([])
    Win_con_op.append([])
    Big_board_position.append([])
    Big_board_possible_red.append([])
    Big_board_possible_blue.append([])
    ref_N.append('N')
    for b in range(board_size):
        position[a].append([])
        blue_possible[a].append([])
        red_possible[a].append([])
        Win_con_op[a].append(0)
        Big_board_position[a].append(0)
        Big_board_possible_red[a].append('Y')
        Big_board_possible_blue[a].append('Y')
        for c in range(board_size):
            position[a][b].append([])
            blue_possible[a][b].append([])
            red_possible[a][b].append([])
            for d in range(board_size):
                position[a][b][c].append(0)
                blue_possible[a][b][c].append('Y')
                red_possible[a][b][c].append('Y')
        

#All the surfaces we will use
static_img_1 = pygame.Surface(window_size,pygame.SRCALPHA)
static_img_2 = pygame.Surface(window_size,pygame.SRCALPHA) 
static_img_3 = pygame.Surface(window_size,pygame.SRCALPHA)
active_board_img_1 = pygame.Surface(window_size,pygame.SRCALPHA) 
active_board_img_2 = pygame.Surface(window_size,pygame.SRCALPHA) 
blinking_1 = pygame.Surface(window_size,pygame.SRCALPHA)
blinking_2 = pygame.Surface(window_size,pygame.SRCALPHA)
#Start Drawing Board
INNER_MARGIN = 5
OUTER_MARGIN = 10
TOTAL_MARGIN = OUTER_MARGIN*2 + INNER_MARGIN*board_size

WIDTH = window_size[0] // board_size
HEIGHT = window_size[1] // board_size


pygame.draw.polygon(static_img_2, black, [(0,0), (window_size[0], 0), (window_size[0], window_size[1]), (0,window_size[1])], width = INNER_MARGIN)

small_board_size = (window_size[0]//board_size,window_size[1]//board_size)
small_width = WIDTH // board_size
small_height = HEIGHT // board_size

small_center_list = []
small_radius = (small_width // 2) - 2

for a in range(board_size):
    small_center_list.append([])
    for b in range(board_size):
        pygame.draw.line(static_img_1, black, (0,(INNER_MARGIN // 2 + 1) + (HEIGHT*b)), 
                         (window_size[0], (INNER_MARGIN // 2 + 1) + (HEIGHT*b)), width = 2)
        pygame.draw.line(static_img_1, black, ((INNER_MARGIN // 2 + 1) + (WIDTH*a),0), 
                         ((INNER_MARGIN // 2 + 1) + (WIDTH*a), window_size[1]), width = 2)
        small_center_list[a].append([])
        for c in range(board_size): #Draw the circle
            small_center_list[a][b].append([])
            for d in range(board_size):
                small_center = (INNER_MARGIN + (WIDTH*a) + (small_radius + (small_width*c)),
                                INNER_MARGIN + (HEIGHT*b) + (small_radius + (small_height*d)))
                small_center_list[a][b][c].append(small_center)
                pygame.draw.circle(static_img_3, black, small_center_list[a][b][c][d], small_radius, width = 3)
                pygame.draw.circle(static_img_1, white, small_center_list[a][b][c][d], small_radius-3, width = 0)
                
        for c in range(board_size):
            for d in range(board_size):
                pygame.draw.line(static_img_3, black, small_center_list[a][b][c][0], small_center_list[a][b][c][board_size-1], width = INNER_MARGIN)
                pygame.draw.line(static_img_3, black, small_center_list[a][b][0][d], small_center_list[a][b][board_size-1][d], width = INNER_MARGIN)

#End Drawing Board

#Winner Screen
P1_Win = Font.render('Player 1 Wins!' , True , red)
P1_Win_size = Font.size('Player 1 Wins!')
P1_Win_background = pygame.Surface(P1_Win_size,pygame.SRCALPHA)
pygame.draw.polygon(P1_Win_background, white, [(0,0), (P1_Win_size[0], 0), 
                                               (P1_Win_size[0], P1_Win_size[1]), 
                                               (0,P1_Win_size[1])], width = 0)
P2_Win = Font.render('Player 2 Wins' , True , blue)
P2_Win_size = Font.size('Player 2 Wins!')
P2_Win_background = pygame.Surface(P2_Win_size,pygame.SRCALPHA)
pygame.draw.polygon(P2_Win_background, white, [(0,0), (P2_Win_size[0], 0), 
                                               (P2_Win_size[0], P2_Win_size[1]), 
                                               (0,P2_Win_size[1])], width = 0)


screen = pygame.display.set_mode(window_size)
pygame.display.set_caption("Snort on a Grid")
    
done = False
clock = pygame.time.Clock()

k = 0
Winner = 0

alpha = 1
change = True
done = False
blink_spd = 0.6
pos = (0,0)

while not done:
    for event in pygame.event.get(): 
        if event.type == pygame.QUIT: 
            done = True 
        elif event.type == pygame.MOUSEBUTTONDOWN:
            pos = pygame.mouse.get_pos()
            
            
    #Blinking effect      
    if change == True:
        alpha = alpha + blink_spd
        if alpha >= 175:
            change = False
    elif change == False:
        alpha = alpha - blink_spd
        if alpha <= 30:
            change = True
            
            
    for a in range(board_size):
        #Winning Condition
        if ((all(element == ref_N for element in Big_board_possible_red) == True and Winner == 0 and k % 2 == 0)
           or ((all(element == ref_N for element in red_possible[a])) and k % 2 == 0 and Winner == 0 
                and all(element != 1 for element in Win_con_op[a]) == True)):
            Winner = 2
        elif ((all(element == ref_N for element in Big_board_possible_blue) == True and Winner == 0 and k % 2 == 1)
            or ((all(element == ref_N for element in blue_possible[a])) and k % 2 == 1 and Winner == 0
                and all(element != 2 for element in Win_con_op[a]) == True)):
            Winner = 1
        for b in range(board_size):
            #Draw on the big board
            if Big_board_position[a][b] == 1:
                pygame.draw.polygon(active_board_img_1, red, [small_center_list[a][b][0][0], #Top Left
                                            small_center_list[a][b][0][board_size-1], #Top Right
                                            small_center_list[a][b][board_size-1][board_size-1], #Bottom Right
                                            small_center_list[a][b][board_size-1][0]], width = 0) #Bottom Left
            elif Big_board_position[a][b] == 2:
                pygame.draw.polygon(active_board_img_1, blue, [small_center_list[a][b][0][0], #Top Left
                                            small_center_list[a][b][0][board_size-1], #Top Right
                                            small_center_list[a][b][board_size-1][board_size-1], #Bottom Right
                                            small_center_list[a][b][board_size-1][0]], width = 0) #Bottom Left
                
            #Draw the blinking effect for big board
            if (Win_con_op[a][b] == 1
                and Big_board_possible_red[a][b] == 'Y' 
                and Big_board_position[a][b] == 0 and k % 2 == 0):
                pygame.draw.polygon(blinking_1, red, [small_center_list[a][b][0][0], #Top Left
                                            small_center_list[a][b][0][board_size-1], #Top Right
                                            small_center_list[a][b][board_size-1][board_size-1], #Bottom Right
                                            small_center_list[a][b][board_size-1][0]], width = 0) #Bottom Left
            elif (Win_con_op[a][b] == 2 
              and Big_board_possible_blue[a][b] == 'Y' 
              and Big_board_position[a][b] == 0 and k % 2 == 1):
                pygame.draw.polygon(blinking_1, blue, [small_center_list[a][b][0][0], #Top Left
                                            small_center_list[a][b][0][board_size-1], #Top Right
                                            small_center_list[a][b][board_size-1][board_size-1], #Bottom Right
                                            small_center_list[a][b][board_size-1][0]], width = 0) #Bottom Left
            else:
                pygame.draw.polygon(blinking_1, white, [small_center_list[a][b][0][0], #Top Left
                                            small_center_list[a][b][0][board_size-1], #Top Right
                                            small_center_list[a][b][board_size-1][board_size-1], #Bottom Right
                                            small_center_list[a][b][board_size-1][0]], width = 0) #Bottom Left  
                
            #Check the board state
            if (all(i == ref_N for i in red_possible[a][b]) == True and k % 2 == 0):
                if next_game == (a,b):
                    next_game = (n+1,n+1) 
                    #If there is no possible move on a board i, then the player free to move anywhere
                if (Win_con_op[a][b] == 0):
                    Win_con_op[a][b] = 2 # small boards winning conditions checks

            if (all(i == ref_N for i in blue_possible[a][b]) == True and k % 2 == 1):
                if next_game == (a,b):
                    next_game = (n+1,n+1) 
                    #If there is no possible move on a board i, then the player free to move anywhere
                if (Win_con_op[a][b] == 0):
                    Win_con_op[a][b] = 1 # small boards winning conditions checks
            for c in range(board_size):
                for d in range(board_size):
                    #Small Board Instruction
                    if ((small_center_list[a][b][c][d][0] - small_radius) < pos[0]
                       and pos[0] < (small_center_list[a][b][c][d][0] + small_radius)
                       and (small_center_list[a][b][c][d][1] - small_radius) < pos[1]
                       and pos[1] < (small_center_list[a][b][c][d][1] + small_radius)):
                        if k % 2 == 0 and position[a][b][c][d] == 0 and (next_game == (n+1,n+1) or next_game == (a,b)):
                            if c == 0: #Top Row
                                if d == 0:  #Left Top Corner Case
                                    if (position[a][b][c][d+1] == 2 or position[a][b][c+1][d] == 2):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1: #Right Top Corner
                                    if (position[a][b][c][d-1] == 2 or position[a][b][c+1][d] == 2):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d-1] == 2 
                                        or position[a][b][c][d+1] == 2 
                                        or position[a][b][c+1][d] == 2): 
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                            elif c == (board_size) - 1: #Bottom Row
                                if d == 0: #Left Bottom Corner
                                    if position[a][b][c][d+1] == 2 or position[a][b][c-1][d] == 2:
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1:#Right Bottom Corner
                                    if position[a][b][c][d-1] == 2 or position[a][b][c-1][d] == 2:
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d-1] == 2 
                                        or position[a][b][c][d+1] == 2 
                                        or position[a][b][c-1][d] == 2): 
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                            else:
                                if d == 0:
                                    if (position[a][b][c][d+1] == 2 
                                        or position[a][b][c-1][d] == 2 
                                        or position[a][b][c+1][d] == 2):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        blue_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1:#Right Bottom Corner
                                    if (position[a][b][c][d-1] == 2 
                                        or position[a][b][c-1][d] == 2 
                                        or position[a][b][c+1][d] == 2):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        blue_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d+1] == 2 
                                        or position[a][b][c][d-1] == 2 
                                        or position[a][b][c-1][d] == 2 
                                        or position[a][b][c+1][d] == 2):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 1
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d-1] = 'N'
                                        blue_possible[a][b][c][d+1] = 'N'
                                        blue_possible[a][b][c-1][d] = 'N'
                                        blue_possible[a][d][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                        elif (k % 2 == 1 and position[a][b][c][d] == 0
                           and (next_game == (n+1,n+1) or next_game == (a,b))):
                            if c == 0: #Top Row
                                if d == 0:  #Left Top Corner Case
                                    if (position[a][b][c][d+1] == 1 or position[a][b][c+1][d] == 1):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1: #Right Top Corner
                                    if (position[a][b][c][d-1] == 1 or position[a][b][c+1][d] == 1):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d-1] == 1 
                                        or position[a][b][c][d+1] == 1 
                                        or position[a][b][c+1][d] == 1): 
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                            elif c == (board_size) - 1: #Bottom Row
                                if d == 0: #Left Bottom Corner
                                    if position[a][b][c][d+1] == 1 or position[a][b][c-1][d] == 1:
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1:#Right Bottom Corner
                                    if position[a][b][c][d-1] == 1 or position[a][b][c-1][d] == 1:
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d-1] == 1 
                                        or position[a][b][c][d+1] == 1 
                                        or position[a][b][c-1][d] == 1): 
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                            else:
                                if d == 0:
                                    if (position[a][b][c][d+1] == 1 
                                        or position[a][b][c-1][d] == 1 
                                        or position[a][b][c+1][d] == 1):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        red_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                elif d == (board_size) - 1:#Right Bottom Corner
                                    if (position[a][b][c][d-1] == 1 
                                        or position[a][b][c-1][d] == 1 
                                        or position[a][b][c+1][d] == 1):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        red_possible[a][b][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                                else:
                                    if (position[a][b][c][d+1] == 1 
                                        or position[a][b][c][d-1] == 1 
                                        or position[a][b][c-1][d] == 1 
                                        or position[a][b][c+1][d] == 1):
                                        position[a][b][c][d] = 0
                                    else:
                                        position[a][b][c][d] = 2
                                        red_possible[a][b][c][d] = 'N'
                                        blue_possible[a][b][c][d] = 'N'
                                        red_possible[a][b][c][d-1] = 'N'
                                        red_possible[a][b][c][d+1] = 'N'
                                        red_possible[a][b][c-1][d] = 'N'
                                        red_possible[a][d][c+1][d] = 'N'
                                        k = k + 1
                                        next_game = (c,d)
                    #Big Board Instruction:
                    if (Big_board_position[a][b] == 0
                        and (small_center_list[a][b][0][0][0] < pos[0]
                        and pos[0] < small_center_list[a][b][board_size-1][board_size-1][0]
                        and small_center_list[a][b][0][0][1] < pos[1]
                        and pos[1] < small_center_list[a][b][board_size-1][board_size-1][1]
                        and (((small_center_list[a][b][c][d][0] - small_radius) > pos[0]
                        or pos[0] > (small_center_list[a][b][c][d][0] + small_radius))
                        and ((small_center_list[a][b][c][d][1] - small_radius) > pos[1]
                        or pos[1] > (small_center_list[a][b][c][d][1] + small_radius))
                       ))):   
                        if Win_con_op[a][b] == 1 and k % 2 == 0:
                            if a == 0:
                                if b == 0: #Top Row
                                    if Big_board_position[a][b+1] == 2 or Big_board_position[a+1][b] == 2:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if Big_board_position[a][b-1] == 2 or Big_board_position[a+1][b] == 2:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b-1] == 2 
                                            or Big_board_position[a][b+1] == 2 
                                            or Big_board_position[a+1][b] == 2): 
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                            elif a == (board_size) - 1: #Bottom Row
                                if b == 0:
                                    if Big_board_position[a][b+1] == 2 or Big_board_position[a-1][b] == 2:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if Big_board_position[a][b-1] == 2 or Big_board_position[a-1][b] == 2:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b-1] == 2 
                                       or Big_board_position[a][b+1] == 2
                                       or Big_board_position[a-1][b] == 2):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                            else:   
                                if b == 0:
                                    if (Big_board_position[a][b+1] == 2 
                                       or Big_board_position[a-1][b] == 2
                                       or Big_board_position[a+1][b] == 2):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if (Big_board_position[a][b-1] == 2 
                                       or Big_board_position[a-1][b] == 2
                                       or Big_board_position[a+1][b] == 2):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b+1] == 2
                                       or Big_board_position[a][b-1] == 2 
                                       or Big_board_position[a-1][b] == 2
                                       or Big_board_position[a+1][b] == 2):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 1
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_blue[a][b+1] = 'N'
                                        Big_board_possible_blue[a][b-1] = 'N'
                                        Big_board_possible_blue[a+1][b] = 'N'
                                        Big_board_possible_blue[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                        elif (Win_con_op[a][b] == 2 and k % 2 == 1):
                            if a == 0:
                                if b == 0: #Top Row
                                    if Big_board_position[a][b+1] == 1 or Big_board_position[a+1][b] == 1:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if Big_board_position[a][b-1] == 1 or Big_board_position[a+1][b] == 1:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b-1] == 1 
                                            or Big_board_position[a][b+1] == 1 
                                            or Big_board_position[a+1][b] == 1): 
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                            elif a == (board_size) - 1: #Bottom Row
                                if b == 0:
                                    if Big_board_position[a][b+1] == 1 or Big_board_position[a-1][b] == 1:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if Big_board_position[a][b-1] == 1 or Big_board_position[a-1][b] == 1:
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b-1] == 1 
                                       or Big_board_position[a][b+1] == 1
                                       or Big_board_position[a-1][b] == 1):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                            else:   
                                if b == 0:
                                    if (Big_board_position[a][b+1] == 1 
                                       or Big_board_position[a-1][b] == 1
                                       or Big_board_position[a+1][b] == 1):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                elif b == (board_size) - 1:
                                    if (Big_board_position[a][b-1] == 1 
                                       or Big_board_position[a-1][b] == 1
                                       or Big_board_position[a+1][b] == 1):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                else:
                                    if (Big_board_position[a][b+1] == 1
                                       or Big_board_position[a][b-1] == 1 
                                       or Big_board_position[a-1][b] == 1
                                       or Big_board_position[a+1][b] == 1):
                                        Big_board_position[a][b] = 0
                                    else:
                                        Big_board_position[a][b] = 2
                                        Big_board_possible_red[a][b] = 'N'
                                        Big_board_possible_blue[a][b] = 'N'
                                        Big_board_possible_red[a][b+1] = 'N'
                                        Big_board_possible_red[a][b-1] = 'N'
                                        Big_board_possible_red[a+1][b] = 'N'
                                        Big_board_possible_red[a-1][b] = 'N'
                                        k = k + 1
                                        Win_con_op[a][b] = 0
                                    
                    if position[a][b][c][d] == 1:
                        pygame.draw.circle(active_board_img_2,red,small_center_list[a][b][c][d],small_radius-3,width=0)
                    elif position[a][b][c][d] == 2:
                        pygame.draw.circle(active_board_img_2,blue,small_center_list[a][b][c][d],small_radius-3,width=0)
                        
                    if (red_possible[a][b][c][d] == 'Y' 
                          and position[a][b][c][d] == 0
                          and k % 2 == 0 
                          and (next_game == (n+1,n+1) or next_game == (a,b))
                          ):
                        pygame.draw.circle(blinking_2,red,small_center_list[a][b][c][d],small_radius-3,width=3)
                    elif (blue_possible[a][b][c][d] == 'Y' 
                          and position[a][b][c][d] == 0
                          and k % 2 == 1 
                          and (next_game == (n+1,n+1) or next_game == (a,b))
                          ):
                        pygame.draw.circle(blinking_2,blue,small_center_list[a][b][c][d],small_radius-3,width=3)
                    else:
                        pygame.draw.circle(blinking_2,white,small_center_list[a][b][c][d],small_radius-3,width=3)
            
    blinking_1.set_alpha(alpha)  
    blinking_2.set_alpha(alpha)        
    pos = (0,0)
            
    screen.fill(white) #Background color 
    screen.blit(blinking_1,(0,0))
    screen.blit(active_board_img_1,(0,0))
    screen.blit(static_img_3,(0,0))
    screen.blit(static_img_1,(0,0))
    screen.blit(static_img_2,(0,0))
    screen.blit(blinking_2,(0,0))
    screen.blit(active_board_img_2,(0,0))

    if Winner == 1:
        screen.blit(P1_Win_background,((window_size[0] // 2) - (P1_Win_size[0] // 2),
                            (window_size[1] // 2) - (P1_Win_size[1] // 2)))
        screen.blit(P1_Win,((window_size[0] // 2) - (P1_Win_size[0] // 2),
                            (window_size[1] // 2) - (P1_Win_size[1] // 2)))
    elif Winner == 2:
        screen.blit(P2_Win_background,((window_size[0] // 2) - (P2_Win_size[0] // 2),
                            (window_size[1] // 2) - (P2_Win_size[1] // 2)))
        screen.blit(P2_Win,((window_size[0] // 2) - (P2_Win_size[0] // 2),
                            (window_size[1] // 2) - (P2_Win_size[1] // 2)))
        


    pygame.display.flip()

# %%
pygame.quit()

# %%
#Debugging information

print('k', k)
print('position', position)
print('blue_possible', blue_possible)
print('red_possible', red_possible)
print('Win_con_op', Win_con_op)
print('Big_board_position', Big_board_position)
print('Big_board_possible_red', Big_board_possible_red)
print('Big_board_possible_blue', Big_board_possible_blue)
print('Winner', Winner)
# Out:
# count 7
# position [[[[1, 0], [0, 2]], [[0, 0], [0, 0]]], [[[2, 0], [0, 0]], [[1, 0], [0, 1]]]]
# blue_possible [[[['N', 'N'], ['N', 'N']], [['Y', 'Y'], ['Y', 'Y']]], [[['N', 'Y'], ['Y', 'Y']], [['N', 'N'], ['N', 'N']]]]
# red_possible [[[['N', 'N'], ['N', 'N']], [['Y', 'Y'], ['Y', 'Y']]], [[['N', 'N'], ['N', 'Y']], [['N', 'Y'], ['Y', 'N']]]]
# Win_con_op [[1, 0], [0, 1]]
# Big_board_position [[2, 0], [0, 1]]
# Big_board_possible_red [['N', 'N'], ['N', 'N']]
# Big_board_possible_blue [['N', 'N'], ['N', 'N']]
# Winner 2
